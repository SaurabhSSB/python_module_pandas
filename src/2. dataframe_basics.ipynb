# %%
import pandas as pd
df= pd.read_csv("C:\\Users\\Hp\\Desktop\\Programs\\python_module_pandas\\src\\IMDB Top 250 Movies.csv")

# %%
df.head()
# Out:
#    rank                      name  year  rating               genre  \
# 0     1  The Shawshank Redemption  1994     9.3               Drama
# 1     2             The Godfather  1972     9.2         Crime,Drama
# 2     3           The Dark Knight  2008     9.0  Action,Crime,Drama
# 3     4     The Godfather Part II  1974     9.0         Crime,Drama
# 4     5              12 Angry Men  1957     9.0         Crime,Drama
#
#   certificate run_time                                            tagline  \
# 0           R   2h 22m  Fear can hold you prisoner. Hope can set you f...
# 1           R   2h 55m                         An offer you can't refuse.
# 2       PG-13   2h 32m                                    Why So Serious?
# 3           R   3h 22m       All the power on earth can't change destiny.
# 4    Approved   1h 36m  Life Is In Their Hands -- Death Is On Their Mi...
#
#       budget  box_office                                              casts  \
# ...

# %%
df.columns
# Out:
# Index(['rank', 'name', 'year', 'rating', 'genre', 'certificate', 'run_time',
#        'tagline', 'budget', 'box_office', 'casts', 'directors', 'writers'],
#       dtype='object')

# %%
df.certificate.unique()
# Out:
# array(['R', 'PG-13', 'Approved', 'PG', '18+', 'Not Rated', 'G', 'Passed',
#        'Not Available', 'TV-PG', 'Unrated', 'X', '13+', 'TV-MA', 'GP'],
#       dtype=object)

# %%
df['year'].unique()
# Out:
# array([1994, 1972, 2008, 1974, 1957, 1993, 2003, 2001, 1966, 1999, 2002,
#        2010, 1980, 1990, 1975, 1995, 1954, 1946, 1991, 1998, 2014, 1997,
#        1977, 1985, 1960, 2019, 2000, 2006, 1942, 1988, 1962, 2011, 1936,
#        1968, 1979, 1931, 2012, 1981, 1950, 1940, 2018, 1986, 1964, 2009,
#        1984, 2017, 2016, 1952, 1963, 1983, 2004, 1992, 1941, 1959, 1958,
#        1971, 1944, 1987, 2022, 2020, 1973, 1927, 1976, 1989, 1948, 2007,
#        1965, 2005, 1921, 2013, 1961, 2021, 1982, 1939, 2015, 1996, 1925,
#        1926, 1949, 1978, 1953, 1924, 1928, 1955, 1967, 1934])

# %%
df.certificate.value_counts()
# Out:
# certificate
# R                97
# PG               37
# PG-13            35
# Not Rated        24
# G                19
# Passed           16
# Approved         14
# 18+               1
# Not Available     1
# TV-PG             1
# Unrated           1
# X                 1
# 13+               1
# TV-MA             1
# GP                1
# Name: count, dtype: int64

# %%
df.year.value_counts()
# Out:
# year
# 1995    8
# 2004    7
# 2003    6
# 1999    6
# 2019    6
#        ..
# 1924    1
# 1928    1
# 1955    1
# 1967    1
# 1934    1
# Name: count, Length: 86, dtype: int64

# %%
df_modified= df[[ "name", "year", "certificate", "rating"]]
df_modified
# Out:
#                          name  year certificate  rating
# 0    The Shawshank Redemption  1994           R     9.3
# 1               The Godfather  1972           R     9.2
# 2             The Dark Knight  2008       PG-13     9.0
# 3       The Godfather Part II  1974           R     9.0
# 4                12 Angry Men  1957    Approved     9.0
# ..                        ...   ...         ...     ...
# 245                  The Help  2011       PG-13     8.1
# 246               Dersu Uzala  1975           G     8.2
# 247                   Aladdin  1992           G     8.0
# 248                    Gandhi  1982          PG     8.0
# 249        Dances with Wolves  1990       PG-13     8.0
#
# [250 rows x 4 columns]

# %%
df_new= df_modified[(df_modified.year>= 2002) & (df_modified.year<=2010)]
df_new
# Out:
#                                                   name  year certificate  \
# 2                                      The Dark Knight  2008       PG-13
# 6        The Lord of the Rings: The Return of the King  2003       PG-13
# 12               The Lord of the Rings: The Two Towers  2002       PG-13
# 13                                           Inception  2010       PG-13
# 22                                         City of God  2002           R
# 31                                         The Pianist  2002           R
# 38                                        The Departed  2006           R
# 40                                        The Prestige  2006       PG-13
# 56                                              WALL·E  2008           G
# 57                                 The Lives of Others  2006           R
# 69                                              Oldboy  2003           R
# 70                                Inglourious Basterds  2009           R
# ...

# %%
df_new[df_new.certificate== 'R']
# Out:
#                                       name  year certificate  rating
# 22                             City of God  2002           R     8.6
# 31                             The Pianist  2002           R     8.5
# 38                            The Departed  2006           R     8.5
# 57                     The Lives of Others  2006           R     8.4
# 69                                  Oldboy  2003           R     8.4
# 70                    Inglourious Basterds  2009           R     8.3
# 89   Eternal Sunshine of the Spotless Mind  2004           R     8.3
# 108                              Incendies  2010           R     8.3
# 123                               Downfall  2004           R     8.2
# 136                        Pan's Labyrinth  2006           R     8.2
# 138                    There Will Be Blood  2007           R     8.2
# 141                         Shutter Island  2010           R     8.2
# 148                 No Country for Old Men  2007           R     8.2
# ...

# %%
df_new.describe()
# Out:
#               year     rating
# count    43.000000  43.000000
# mean   2005.953488   8.295349
# std       2.672198   0.239994
# min    2002.000000   8.000000
# 25%    2004.000000   8.100000
# 50%    2006.000000   8.200000
# 75%    2008.500000   8.400000
# max    2010.000000   9.000000

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 43 entries, 2 to 234
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         43 non-null     object
#  1   year         43 non-null     int64
#  2   certificate  43 non-null     object
#  3   rating       43 non-null     float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 1.7+ KB

# %%
df_new[(df_new.rating>8.5) & (df_new.rating<9)]
# Out:
#                                      name  year certificate  rating
# 12  The Lord of the Rings: The Two Towers  2002       PG-13     8.8
# 13                              Inception  2010       PG-13     8.8
# 22                            City of God  2002           R     8.6

# %%
float(df_new.rating.max())
# Out:
# 9.0

# %%
df_new[df_new.rating== df_new.rating.max()]
# Out:
#                                             name  year certificate  rating
# 2                                The Dark Knight  2008       PG-13     9.0
# 6  The Lord of the Rings: The Return of the King  2003       PG-13     9.0

# %%
df_new[(df_new.rating == df_new.rating.max()) | (df_new.rating == df_new.rating.min())]
# Out:
#                                               name  year certificate  rating
# 2                                  The Dark Knight  2008       PG-13     9.0
# 6    The Lord of the Rings: The Return of the King  2003       PG-13     9.0
# 226                                The Incredibles  2004          PG     8.0

# %%
df['age']= df.year.apply( lambda x: 2025 - x)
df.head()
# Out:
#    rank                      name  year  rating               genre  \
# 0     1  The Shawshank Redemption  1994     9.3               Drama
# 1     2             The Godfather  1972     9.2         Crime,Drama
# 2     3           The Dark Knight  2008     9.0  Action,Crime,Drama
# 3     4     The Godfather Part II  1974     9.0         Crime,Drama
# 4     5              12 Angry Men  1957     9.0         Crime,Drama
#
#   certificate run_time                                            tagline  \
# 0           R   2h 22m  Fear can hold you prisoner. Hope can set you f...
# 1           R   2h 55m                         An offer you can't refuse.
# 2       PG-13   2h 32m                                    Why So Serious?
# 3           R   3h 22m       All the power on earth can't change destiny.
# 4    Approved   1h 36m  Life Is In Their Hands -- Death Is On Their Mi...
#
#       budget  box_office                                              casts  \
# ...

# %%
df_copy= df_new.copy()
df_copy["age"]= df_copy["year"].apply( lambda x: 2025 - x)
df_copy.head()
# Out:
#                                              name  year certificate  rating  \
# 2                                 The Dark Knight  2008       PG-13     9.0
# 6   The Lord of the Rings: The Return of the King  2003       PG-13     9.0
# 12          The Lord of the Rings: The Two Towers  2002       PG-13     8.8
# 13                                      Inception  2010       PG-13     8.8
# 22                                    City of God  2002           R     8.6
#
#     age
# 2    17
# 6    22
# 12   23
# 13   15
# 22   23

# %%
# Replace non-numeric values with NaN
df['box_office']= pd.to_numeric(df['box_office'], errors='coerce')
df['budget']= pd.to_numeric(df['budget'], errors= 'coerce')

# Fill NaN values if needed (e.g., with 0)
df['box_office'] = df['box_office'].fillna(0).astype(int)
df['budget']= df['budget'].fillna(0).astype(int)

# If you prefer to keep NaNs, use Pandas' nullable integer type
df['box_office'] = df['box_office'].astype(pd.Int64Dtype())
df['budget']= df['budget'].astype(pd.Int64Dtype())

# %%
df['profit']= df.apply(lambda x: x['box_office'] - x['budget'], axis= 1)
df.head()
# Out:
#    rank                      name  year  rating               genre  \
# 0     1  The Shawshank Redemption  1994     9.3               Drama
# 1     2             The Godfather  1972     9.2         Crime,Drama
# 2     3           The Dark Knight  2008     9.0  Action,Crime,Drama
# 3     4     The Godfather Part II  1974     9.0         Crime,Drama
# 4     5              12 Angry Men  1957     9.0         Crime,Drama
#
#   certificate run_time                                            tagline  \
# 0           R   2h 22m  Fear can hold you prisoner. Hope can set you f...
# 1           R   2h 55m                         An offer you can't refuse.
# 2       PG-13   2h 32m                                    Why So Serious?
# 3           R   3h 22m       All the power on earth can't change destiny.
# 4    Approved   1h 36m  Life Is In Their Hands -- Death Is On Their Mi...
#
#       budget  box_office                                              casts  \
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=250, step=1)

# %% [markdown]
# ### This will remove all rows where 'name' has null values
# df = df.dropna(subset=['name'])
# df.index

# %%
df.set_index("name", inplace= True)
df.head(3)
# Out:
#                           rank  year  rating               genre certificate  \
# name
# The Shawshank Redemption     1  1994     9.3               Drama           R
# The Godfather                2  1972     9.2         Crime,Drama           R
# The Dark Knight              3  2008     9.0  Action,Crime,Drama       PG-13
#
#                          run_time  \
# name
# The Shawshank Redemption   2h 22m
# The Godfather              2h 55m
# The Dark Knight            2h 32m
#
#                                                                     tagline  \
# name
# The Shawshank Redemption  Fear can hold you prisoner. Hope can set you f...
# The Godfather                                    An offer you can't refuse.
# The Dark Knight                                             Why So Serious?
#
#                              budget  box_office  \
# name
# The Shawshank Redemption   25000000    28884504
# The Godfather               6000000   250341816
# ...

# %%
df.index
# Out:
# Index(['The Shawshank Redemption', 'The Godfather', 'The Dark Knight',
#        'The Godfather Part II', '12 Angry Men', 'Schindler's List',
#        'The Lord of the Rings: The Return of the King', 'Pulp Fiction',
#        'The Lord of the Rings: The Fellowship of the Ring',
#        'The Good, the Bad and the Ugly',
#        ...
#        'The Sound of Music', 'It Happened One Night', 'Persona',
#        'Life of Brian', 'The Iron Giant', 'The Help', 'Dersu Uzala', 'Aladdin',
#        'Gandhi', 'Dances with Wolves'],
#       dtype='object', name='name', length=250)

# %%
df.loc['The Dark Knight']
# Out:
# rank                                                           3
# year                                                        2008
# rating                                                       9.0
# genre                                         Action,Crime,Drama
# certificate                                                PG-13
# run_time                                                  2h 32m
# tagline                                          Why So Serious?
# budget                                                 185000000
# box_office                                            1006234167
# casts          Christian Bale,Heath Ledger,Aaron Eckhart,Mich...
# directors                                      Christopher Nolan
# writers          Jonathan Nolan,Christopher Nolan,David S. Goyer
# age                                                           17
# profit                                                 821234167
# Name: The Dark Knight, dtype: object

# %%
df.loc[['The Dark Knight','The Godfather Part II']]
# Out:
#                        rank  year  rating               genre certificate  \
# name
# The Dark Knight           3  2008     9.0  Action,Crime,Drama       PG-13
# The Godfather Part II     4  1974     9.0         Crime,Drama           R
#
#                       run_time                                       tagline  \
# name
# The Dark Knight         2h 32m                               Why So Serious?
# The Godfather Part II   3h 22m  All the power on earth can't change destiny.
#
#                           budget  box_office  \
# name
# The Dark Knight        185000000  1006234167
# The Godfather Part II   13000000    47961919
#
#                                                                    casts  \
# name
# The Dark Knight        Christian Bale,Heath Ledger,Aaron Eckhart,Mich...
# The Godfather Part II  Al Pacino,Robert De Niro,Robert Duvall,Diane K...
#
#                                   directors  \
# name
# The Dark Knight           Christopher Nolan
# ...

# %%
df.iloc[0]
# Out:
# rank                                                           1
# year                                                        1994
# rating                                                       9.3
# genre                                                      Drama
# certificate                                                    R
# run_time                                                  2h 22m
# tagline        Fear can hold you prisoner. Hope can set you f...
# budget                                                  25000000
# box_office                                              28884504
# casts          Tim Robbins,Morgan Freeman,Bob Gunton,William ...
# directors                                         Frank Darabont
# writers                              Stephen King,Frank Darabont
# age                                                           31
# profit                                                   3884504
# Name: The Shawshank Redemption, dtype: object

# %%
df.iloc[2:6]
# Out:
#                        rank  year  rating                    genre  \
# name
# The Dark Knight           3  2008     9.0       Action,Crime,Drama
# The Godfather Part II     4  1974     9.0              Crime,Drama
# 12 Angry Men              5  1957     9.0              Crime,Drama
# Schindler's List          6  1993     9.0  Biography,Drama,History
#
#                       certificate run_time  \
# name
# The Dark Knight             PG-13   2h 32m
# The Godfather Part II           R   3h 22m
# 12 Angry Men             Approved   1h 36m
# Schindler's List                R   3h 15m
#
#                                                                  tagline  \
# name
# The Dark Knight                                          Why So Serious?
# The Godfather Part II       All the power on earth can't change destiny.
# 12 Angry Men           Life Is In Their Hands -- Death Is On Their Mi...
# Schindler's List         Whoever saves one life, saves the world entire.
#
# ...

# %%
df.reset_index(inplace= True)
df.head(4)
# Out:
#                        name  rank  year  rating               genre  \
# 0  The Shawshank Redemption     1  1994     9.3               Drama
# 1             The Godfather     2  1972     9.2         Crime,Drama
# 2           The Dark Knight     3  2008     9.0  Action,Crime,Drama
# 3     The Godfather Part II     4  1974     9.0         Crime,Drama
#
#   certificate run_time                                            tagline  \
# 0           R   2h 22m  Fear can hold you prisoner. Hope can set you f...
# 1           R   2h 55m                         An offer you can't refuse.
# 2       PG-13   2h 32m                                    Why So Serious?
# 3           R   3h 22m       All the power on earth can't change destiny.
#
#       budget  box_office                                              casts  \
# 0   25000000    28884504  Tim Robbins,Morgan Freeman,Bob Gunton,William ...
# 1    6000000   250341816  Marlon Brando,Al Pacino,James Caan,Diane Keato...
# ...

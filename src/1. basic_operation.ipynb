# %%
import pandas as pd
df= pd.read_csv("C:\\Users\\Hp\\Desktop\\Programs\\python_module_pandas\\src\\IMDB Top 250 Movies.csv")

# %%
df
# Out:
#      rank                      name  year  rating                       genre  \
# 0       1  The Shawshank Redemption  1994     9.3                       Drama
# 1       2             The Godfather  1972     9.2                 Crime,Drama
# 2       3           The Dark Knight  2008     9.0          Action,Crime,Drama
# 3       4     The Godfather Part II  1974     9.0                 Crime,Drama
# 4       5              12 Angry Men  1957     9.0                 Crime,Drama
# ..    ...                       ...   ...     ...                         ...
# 245   246                  The Help  2011     8.1                       Drama
# 246   247               Dersu Uzala  1975     8.2   Adventure,Biography,Drama
# 247   248                   Aladdin  1992     8.0  Animation,Adventure,Comedy
# 248   249                    Gandhi  1982     8.0     Biography,Drama,History
# 249   250        Dances with Wolves  1990     8.0     Adventure,Drama,Western
#
# ...

# %%
df.head()
# Out:
#    rank                      name  year  rating               genre  \
# 0     1  The Shawshank Redemption  1994     9.3               Drama
# 1     2             The Godfather  1972     9.2         Crime,Drama
# 2     3           The Dark Knight  2008     9.0  Action,Crime,Drama
# 3     4     The Godfather Part II  1974     9.0         Crime,Drama
# 4     5              12 Angry Men  1957     9.0         Crime,Drama
#
#   certificate run_time                                            tagline  \
# 0           R   2h 22m  Fear can hold you prisoner. Hope can set you f...
# 1           R   2h 55m                         An offer you can't refuse.
# 2       PG-13   2h 32m                                    Why So Serious?
# 3           R   3h 22m       All the power on earth can't change destiny.
# 4    Approved   1h 36m  Life Is In Their Hands -- Death Is On Their Mi...
#
#       budget  box_office                                              casts  \
# ...

# %%
df.head(3)
# Out:
#    rank                      name  year  rating               genre  \
# 0     1  The Shawshank Redemption  1994     9.3               Drama
# 1     2             The Godfather  1972     9.2         Crime,Drama
# 2     3           The Dark Knight  2008     9.0  Action,Crime,Drama
#
#   certificate run_time                                            tagline  \
# 0           R   2h 22m  Fear can hold you prisoner. Hope can set you f...
# 1           R   2h 55m                         An offer you can't refuse.
# 2       PG-13   2h 32m                                    Why So Serious?
#
#       budget  box_office                                              casts  \
# 0   25000000    28884504  Tim Robbins,Morgan Freeman,Bob Gunton,William ...
# 1    6000000   250341816  Marlon Brando,Al Pacino,James Caan,Diane Keato...
# 2  185000000  1006234167  Christian Bale,Heath Ledger,Aaron Eckhart,Mich...
#
#               directors                                          writers
# ...

# %%
df.tail()
# Out:
#      rank                name  year  rating                       genre  \
# 245   246            The Help  2011     8.1                       Drama
# 246   247         Dersu Uzala  1975     8.2   Adventure,Biography,Drama
# 247   248             Aladdin  1992     8.0  Animation,Adventure,Comedy
# 248   249              Gandhi  1982     8.0     Biography,Drama,History
# 249   250  Dances with Wolves  1990     8.0     Adventure,Drama,Western
#
#     certificate run_time                                            tagline  \
# 245       PG-13   2h 26m                      Change begins with a whisper.
# 246           G   2h 22m  There is man and beast at nature's mercy. Ther...
# 247           G   1h 30m                     Wish granted! (DVD re-release)
# 248          PG   3h 11m             His Triumph Changed The World Forever.
# 249       PG-13    3h 1m  Inside everyone is a frontier waiting to be di...
#
#             budget     box_office  \
# 245       25000000      216639112
# ...

# %%
df.sample(4)
# Out:
#      rank                      name  year  rating                    genre  \
# 0       1  The Shawshank Redemption  1994     9.3                    Drama
# 135   136                       Ran  1985     8.2         Action,Drama,War
# 216   217               Stand by Me  1986     8.1          Adventure,Drama
# 64     65                    Aliens  1986     8.4  Action,Adventure,Sci-Fi
#
#     certificate run_time                                            tagline  \
# 0             R   2h 22m  Fear can hold you prisoner. Hope can set you f...
# 135           R   2h 42m                                       tionDramaWar
# 216         13+   1h 29m  For some, it's the last real taste of innocenc...
# 64            R   2h 17m                            This time there's more.
#
#        budget box_office                                              casts  \
# 0    25000000   28884504  Tim Robbins,Morgan Freeman,Bob Gunton,William ...
# ...

# %%
df[2:4]
# Out:
#    rank                   name  year  rating               genre certificate  \
# 2     3        The Dark Knight  2008     9.0  Action,Crime,Drama       PG-13
# 3     4  The Godfather Part II  1974     9.0         Crime,Drama           R
#
#   run_time                                       tagline     budget  \
# 2   2h 32m                               Why So Serious?  185000000
# 3   3h 22m  All the power on earth can't change destiny.   13000000
#
#    box_office                                              casts  \
# 2  1006234167  Christian Bale,Heath Ledger,Aaron Eckhart,Mich...
# 3    47961919  Al Pacino,Robert De Niro,Robert Duvall,Diane K...
#
#               directors                                          writers
# 2     Christopher Nolan  Jonathan Nolan,Christopher Nolan,David S. Goyer
# 3  Francis Ford Coppola                  Francis Ford Coppola,Mario Puzo

# %%
df.shape
# Out:
# (250, 13)

# %%
df["name"]
# Out:
# 0      The Shawshank Redemption
# 1                 The Godfather
# 2               The Dark Knight
# 3         The Godfather Part II
# 4                  12 Angry Men
#                  ...
# 245                    The Help
# 246                 Dersu Uzala
# 247                     Aladdin
# 248                      Gandhi
# 249          Dances with Wolves
# Name: name, Length: 250, dtype: object

# %%
df.rating
# Out:
# 0      9.3
# 1      9.2
# 2      9.0
# 3      9.0
# 4      9.0
#       ...
# 245    8.1
# 246    8.2
# 247    8.0
# 248    8.0
# 249    8.0
# Name: rating, Length: 250, dtype: float64

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df.rating)
# Out:
# pandas.core.series.Series

# %%
dir(df.rating)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__bool__',
#  '__class__',
#  '__column_consortium_standard__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
# ...

# %%
df.rating.min(), df.rating.max(), df.rating.mean()
# Out:
# (np.float64(8.0), np.float64(9.3), np.float64(8.3072))

# %%
df_Approved= df[df.certificate== "Approved"]
df_R= df[df.certificate== "R"]

# %%
df_Approved
# Out:
#      rank                            name  year  rating  \
# 4       5                    12 Angry Men  1957     9.0
# 9      10  The Good, the Bad and the Ugly  1966     8.8
# 59     60                  Paths of Glory  1957     8.4
# 63     64     Witness for the Prosecution  1957     8.4
# 96     97              Lawrence of Arabia  1962     8.3
# 97     98              North by Northwest  1959     8.3
# 101   102                   The Apartment  1960     8.3
# 109   110           To Kill a Mockingbird  1962     8.3
# 133   134           Judgment at Nuremberg  1961     8.3
# 147   148                The Great Escape  1963     8.2
# 181   182               On the Waterfront  1954     8.1
# 187   188                   The Third Man  1949     8.1
# 224   225     The Best Years of Our Lives  1946     8.1
# 236   237                         Rebecca  1940     8.1
#
#                           genre certificate run_time  \
# 4                   Crime,Drama    Approved   1h 36m
# ...

# %%
df_R
# Out:
#      rank                      name  year  rating                      genre  \
# 0       1  The Shawshank Redemption  1994     9.3                      Drama
# 1       2             The Godfather  1972     9.2                Crime,Drama
# 3       4     The Godfather Part II  1974     9.0                Crime,Drama
# 5       6          Schindler's List  1993     9.0    Biography,Drama,History
# 7       8              Pulp Fiction  1994     8.9                Crime,Drama
# ..    ...                       ...   ...     ...                        ...
# 219   220             Into the Wild  2007     8.1  Adventure,Biography,Drama
# 220   221             Before Sunset  2004     8.1              Drama,Romance
# 225   226              The Exorcist  1973     8.1                     Horror
# 235   236             Amores Perros  2000     8.1             Drama,Thriller
# 243   244             Life of Brian  1979     8.0                     Comedy
#
# ...

# %%
float(df_Approved.rating.min()), float(df_Approved.rating.max()), float(df_Approved.rating.mean())
# Out:
# (8.1, 9.0, 8.335714285714285)

# %%
min_rating = float(df_R.rating.min())
max_rating = float(df_R.rating.max())
mean_rating = float(df_R.rating.mean())

print(min_rating, max_rating, mean_rating)
# Out:
# 8.0 9.3 8.325773195876288
